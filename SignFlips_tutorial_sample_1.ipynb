# %%
import graspologic

import numpy as np
# %matplotlib inline

# %%
# in this example, we generate two graphs from an SBM model with 
# B = [[0.8, 0.2], [0.2, 0.8]] n=100 and p = [0.5, 0.5].
# NOTE THAT CLASS MEMEBERSHIP IS SAMPLED!
from graspologic.simulations import sbm
def make_graphs():
    n_1 = np.random.binomial(100, 0.5)
    ns_1 = [n_1, 100-n_1]
    n_2 = np.random.binomial(100, 0.5)
    ns_2 = [n_2, 100-n_2]
    P = [[0.8, 0.2], [0.2, 0.8]]
    A = sbm(ns_1, P)
    B = sbm(ns_2, P)
    return A, B

# %%
# In this example, the eigenvalues are close enough that the embeddings
# experiences some sort of "orthogonal offset", if one wills.
# here is a visual example of such:
import matplotlib.pyplot as plt
from graspologic.embed import AdjacencySpectralEmbed
np.random.seed(100)
A, B = make_graphs()
ase = AdjacencySpectralEmbed(n_components=2)
X = ase.fit_transform(A)
Y = ase.fit_transform(B)
plt.subplots(1, 1, figsize=(6, 6))
plt.scatter(X[:,0], X[:,1], label="X", alpha=0.3, color='c')
plt.scatter(Y[:,0], Y[:,1], label="Y", alpha=0.3, color='y')
plt.xlim(-1.10, 1.10)
plt.ylim(-1.10, 1.10)
plt.legend()
plt.grid();

# %%
# note that issue cannot be overcome by simple sign flips:
# (it is exactly on top of X)
from graspologic.align import SignFlips
X_prime = SignFlips().fit_transform(X, Y)
plt.subplots(1, 1, figsize=(6, 6))
plt.scatter(X[:,0], X[:,1], label="X", alpha=0.3, color='c')
plt.scatter(Y[:,0], Y[:,1], label="Y", alpha=0.3, color='y')
plt.scatter(X_prime[:,0], X_prime[:,1], label="X@Q_signflips", alpha=0.3, color='m')
plt.xlim(-1.10, 1.10)
plt.ylim(-1.10, 1.10)
plt.legend()
plt.grid();

# %%
# 
# 
X_prime = SignFlips().fit_transform(X, Y)
plt.subplots(1, 1, figsize=(6, 6))
plt.scatter(X_prime[:,0], X_prime[:,1], label="X@Q_signflips", alpha=0.3, color='m')
plt.xlim(-1.10, 1.10)
plt.ylim(-1.10, 1.10)
plt.legend()
plt.grid();

# %%
# 
X_prime = SignFlips().fit_transform(X, Y)
plt.subplots(1, 1, figsize=(6, 6))
plt.scatter(X[:,0], X[:,1], label="X", alpha=0.3, color='c')
plt.xlim(-1.10, 1.10)
plt.ylim(-1.10, 1.10)
plt.legend()
plt.grid();

# %%
# 
X_prime = SignFlips().fit_transform(X, Y)
plt.subplots(1, 1, figsize=(6, 6))
plt.scatter(X[:,0], X[:,1], label="X", alpha=0.3, color='c')
plt.scatter(X_prime[:,0], X_prime[:,1], label="X@Q_signflips", alpha=0.3, color='m')
plt.xlim(-1.10, 1.10)
plt.ylim(-1.10, 1.10)
plt.legend()
plt.grid();
